# %%
from bs4 import BeautifulSoup # Importing the BeautifulSoup package
import requests # Importing requests library
import csv
import pandas as pd

# %%
req=requests.get('https://www.flipkart.com/laptops-store?gclid=Cj0KCQjw6-SDBhCMARIsAGbI7Uj5NDHvG8TLX-ucQuq1OcKc0lb1BNTd9Qgyu_yZz-71dTVolKsm0fwaAjFeEALw_wcB&s_kwcid=AL!739!3!472856528309!e!!g!!flipkart%20laptop&gclsrc=aw.ds&&semcmpid=sem_8024046704_brand_brandandcategory_electronicdevice_laptopanddesktop_goog&ef_id=X1Y7EAAAAGmh43Bj:20210416075504:s')

# %%
content = req.content

# %%
soup = BeautifulSoup(content,'html.parser') # Here we need to specify the content variable and the parser which is the HTML parser

# %%
print(soup.prettify()) # Displays the whole code of the website
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.07395f.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/>
#   <meta content="app" name="twitter:card"/>
#   <meta content="@flipkart" name="twitter:site"/>
#   <meta content="@flipkart" name="twitter:creator"/>
#   <meta content="Laptops : Upto 50% OFF on Laptops with Best Prices &amp; Offers in India | Flipkart.com" name="twitter:title"/>
#   <meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/>
#   <meta content="in" name="twitter:app:country"/>
#   <meta content="Flipkart" name="al:ios:app_name"/>
#   <meta content="742044692" name="al:ios:app_store_id"/>
#   <meta content="Flipkart" name="twitter:app:name:iphone"/>
#   <meta content="742044692" name="twitter:app:id:iphone"/>
#   <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/>
#   <meta content="Flipkart" name="twitter:app:name:ipad"/>
#   <meta content="742044692" name="twitter:app:id:ipad"/>
#   <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/>
#   <meta content="Flipkart" name="twitter:app:name:googleplay"/>
#   <meta content="com.flipkart.android" name="twitter:app:id:googleplay"/>
#   <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/>
#   <style>
#    #container {
# 			height: 100%;
# 		}
#   </style>
#   <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/runtime.4e5cc511.js">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/vendor.chunk.a14af8f3.js">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/app_modules.chunk.49acb7f9.js">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/app_common.chunk.3e0749b0.js">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/app.chunk.d164fce2.js">
#   </script>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/MultiWidgetBase.chunk.5237c1.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/CLP.chunk.969af5.css" rel="stylesheet"/>
#   <title>
#    Laptops : Upto 50% OFF on Laptops with Best Prices &amp; Offers in India | Flipkart.com
#   </title>
#   <meta content="Laptops : Upto 50% OFF on Laptops with Best Prices &amp; Offers in India | Flipkart.com" name="og_title" property="og:title">
#    <meta content="laptops, buy laptops online, india, price, deals, store, offers" name="Keywords">
#     <meta content="Laptop Prices in India - Buy Laptops Online at Lowest Prices on Flipkart.com Choose from a wide range of Laptops from best brands like HP, Dell, Lenovo, Acer, Apple &amp; many more. &amp;#10004; Free Shipping. &amp;#10004; Cash on Delivery &amp;#10004; EMI Offers and Top Deals." name="Description">
#      <meta content="Laptop Prices in India - Buy Laptops Online at Lowest Prices on Flipkart.com Choose from a wide range of Laptops from best brands like HP, Dell, Lenovo, Acer, Apple &amp; many more. &amp;#10004; Free Shipping. &amp;#10004; Cash on Delivery &amp;#10004; EMI Offers and Top Deals." property="og:description">
#       <link href="https://www.flipkart.com/laptops-store" rel="canonical"/>
#       <meta content="https://www.flipkart.com/laptops-store" name="og_url" property="og:url">
#        <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01">
#         <!--[if IE 9 ]>
# 	<script nonce="5691071682612875426">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
#         <!--[if !IE]><!-->
#         <script nonce="5691071682612875426">
#          if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}
#         </script>
#         <!--<![endif]-->
#         <script id="jsonLD" nonce="5691071682612875426" type="application/ld+json">
#          {}
#         </script>
#         <script nonce="5691071682612875426">
#          !function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#         </script>
#         <script nonce="5691071682612875426">
#          if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#         </script>
#         <script nonce="5691071682612875426">
#          // web-vitals polyfill for FID
#         !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);
#         </script>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="container">
#    <div data-reactroot="">
#     <div class="_1kfTjk">
#      <div class="_1rH5Jn">
#       <div class="_1TmfNK">
#       </div>
#       <div class="_2Xfa2_">
#        <div class="_3_C9Hx">
#         <div class="_3qX0zy">
#          <a href="/">
#           <img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" title="Flipkart" width="110"/>
#          </a>
#         </div>
#        </div>
#        <div class="_1cmsER">
#         <form action="/search" class="_2M8cLY header-form-search" method="GET">
#          <div class="col-12-12 _2oO9oE">
#           <div class="_3OO5Xc">
#            <input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/>
#           </div>
#           <button class="L0Z3Pu" type="submit">
#            <svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
#             <g fill="#2874F1" fill-rule="evenodd">
#              <path class="_34RNph" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203">
#              </path>
#              <path class="_34RNph" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467">
#              </path>
#             </g>
#            </svg>
#           </button>
#           <input name="otracker" type="hidden" value="search"/>
#           <input name="otracker1" type="hidden" value="search"/>
#           <input name="marketplace" type="hidden" value="FLIPKART"/>
#           <input name="as-show" type="hidden" value="off"/>
#           <input name="as" type="hidden" value="off"/>
#          </div>
#          <ul class="col-12-12 _1MRYA1">
#          </ul>
#         </form>
#        </div>
#        <div class="go_DOp _2errNR">
#         <div class="_28p97w">
#          <div class="_1psGvi _3BvnxG">
#           <div>
#            <a class="_1_3w1N" href="/account/login?ret=/laptops-store%3Fgclid%3DCj0KCQjw6-SDBhCMARIsAGbI7Uj5NDHvG8TLX-ucQuq1OcKc0lb1BNTd9Qgyu_yZz-71dTVolKsm0fwaAjFeEALw_wcB%26s_kwcid%3DAL!739!3!472856528309!e!!g!!flipkart%2520laptop%26gclsrc%3Daw.ds%26%26semcmpid%3Dsem_8024046704_brand_brandandcategory_electronicdevice_laptopanddesktop_goog%26ef_id%3DX1Y7EAAAAGmh43Bj%3A20210416075504%3As">
#             Login
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="go_DOp">
#         <div class="_28p97w">
#          <div class="_1psGvi _3BvnxG">
#           <div>
#            <div class="exehdJ">
#             <!-- -->
#             More
#             <!-- -->
#            </div>
#           </div>
#          </div>
#          <svg class="zZ3yfL" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg">
#           <path class="_2gTTdy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#           </path>
#          </svg>
#         </div>
#        </div>
#        <div class="go_DOp">
#         <div class="_1psGvi">
#          <div class="YUhWwv">
#           <a class="_3SkBxJ" href="/viewcart?otracker=Cart_Icon_Click">
#            <svg class="V3C5bO" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg">
#             <path class="_1bS9ic" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff">
#             </path>
#            </svg>
#            <span>
#             Cart
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="_1TmfNK">
#       </div>
#      </div>
#      <div class="_1mUdNz">
#      </div>
#     </div>
#     <div class="_331-kn">
#     </div>
#     <div class="_6t1WkM _3HqJxg">
#      <div class="znxK_-">
#       <h1 class="_3vKRL2">
#        Back To School
#       </h1>
#       <div class="col gu12 _1c0opE _1P3kV7">
#        <div class="_1D76KH">
#         <p>
#          Shop from a wide range of laptops from
#          <a href="/laptops/hp~brand/pr?sid=6bo,b5g">
#           HP
#          </a>
#          ,
#          <a href="/laptops/dell~brand/pr?sid=6bo,b5g">
#           Dell
#          </a>
#          ,
#          <a href="/laptops/lenovo~brand/pr?sid=6bo,b5g">
#           Lenovo
#          </a>
#          ,
#          <a href="/laptops/asus~brand/pr?sid=6bo,b5g">
#           Asus
#          </a>
#          ,
#          <a href="/laptops/acer~brand/pr?sid=6bo,b5g">
#           Acer
#          </a>
#          ,
#          <a href="/laptops/vaio~brand/pr?sid=6bo,b5g">
#           Vaio
#          </a>
#          &amp; more at India's Best Online Shopping Store. Avail benefits such as free shipping, no cost EMI, product exchange, extended warranty and assured buyback. Flipkart offers laptops for all kinds of need- Students, Work, Gaming, Thin &amp; Light, Premium etc. Buy laptops that fit in your budget and explore best deals-  Under 30,000, Under 40,000 &amp; Under 50,000. Shop laptop by latest processors and built- Intel Laptops &amp; Ryzen Powered Laptops.
#         </p>
#         <p>
#          <b>
#           Choose among
#          </b>
#          :
#          <a href="/computers/~business-laptops/pr?sid=6bo">
#           Business Laptops
#          </a>
#          |
#          <a href="/laptops/entertainment~lifestyle/pr?sid=6bo,b5g">
#           Entertainment Laptops
#          </a>
#          |
#          <a href="/gaming-laptops-store">
#           Gaming Laptops
#          </a>
#          |
#          <a href="/laptops/everyday-use~lifestyle/pr?sid=6bo,b5g">
#           Everyday use laptops
#          </a>
#         </p>
#         <p>
#          <b>
#           Trending:
#          </b>
#          <span>
#           Back to College Season,
#          </span>
#          <a href="/laptops/~best-selling-specs/pr?sid=6bo,b5g">
#           Laptops at upto 40% Off
#          </a>
#          <span>
#           ,
#          </span>
#          <a href="/acer-aspire-7-core-i5-9th-gen-8-gb-512-gb-ssd-windows-10-home-4-graphics-nvidia-geforce-gtx-1650-a715-75g-50sa-gaming-laptop/p/itmff1cbf710ce62">
#           Acer Aspire 7
#          </a>
#         </p>
#         <p>
#          GST Invoice Available! Save up to 28% with GST input credit on business Purchase. Check out our
#          <a href="/laptops-and-desktops-gst-store">
#           Laptops and Desktops GST Store
#          </a>
#         </p>
#         <p>
#          <br/>
#         </p>
#         <p>
#          <br/>
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="_1AtVbE col-12-12">
#       <div class="_2oNtQM">
#        <div class="qrCnTo" style="padding-top:28.76%;width:100%">
#         <span class="_28Go3e _2JsIUT">
#          <div class="_1bEAQy" style="padding-top:28.76%;width:100%">
#           <img alt="d" class="_2OHU_q"/>
#           <img alt="d" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/flap/50/50/image/220bee42dbd0ca51.jpg?q=50"/>
#          </div>
#         </span>
#        </div>
#        <div class="_3vNIhc">
#        </div>
#       </div>
#      </div>
#      <div class="_1AtVbE col-12-12">
#       <div class="_3WcRHs">
#        <div class="_3ywSr_" style="padding-top:21.58%">
#         <div class="_1bEAQy _312yBx" style="padding-top:21.58%">
#          <img alt="d" class="_2OHU_q"/>
#          <img alt="d" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/flap/100/22/image/18501684530aa5d2.jpg?q=50"/>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="_1AtVbE col-12-12">
#       <div class="_2oNtQM">
#        <div class="qrCnTo" style="padding-top:28.76%;width:100%">
#         <a class="_28Go3e _2JsIUT" href="/laptops/~cs-zokf2sfe0r/pr?sid=6bo%2Cb5g&amp;collection-tab-name=Best%20Selling%20Laptops&amp;param=1&amp;otracker=clp_banner_1_3.banner.BANNER_laptops-store_0WSQY5N5MMHI">
#          <div class="_1bEAQy" style="padding-top:28.76%;width:100%">
#           <img alt="d" class="_2OHU_q"/>
#           <img alt="d" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/flap/50/50/image/1934b5db4aee1ff1.jpg?q=50"/>
#          </div>
#         </a>
#        </div>
#        <div class="_3vNIhc">
#        </div>
#       </div>
#      </div>
#      <div class="_1AtVbE col-12-12">
#       <div class="_2oNtQM">
#        <div class="qrCnTo" style="padding-top:28.76%;width:100%">
#         <a class="_28Go3e _2JsIUT" href="/laptops/~cs-a3ds27t2gg/pr?sid=6bo%2Cb5g&amp;collection-tab-name=Asus&amp;otracker=clp_banner_1_4.banner.BANNER_laptops-store_LWA5FS8H7C2G">
#          <div class="_1bEAQy" style="padding-top:28.76%;width:100%">
#           <img alt="d" class="_2OHU_q"/>
#           <img alt="d" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/flap/50/50/image/de1c457b98e6dc97.jpg?q=50"/>
#          </div>
#         </a>
#        </div>
#        <div class="_3vNIhc">
#        </div>
#       </div>
#      </div>
#      <div class="_1AtVbE col-12-12">
#       <div class="_3E8aIl Zic51i">
#        <div class="Nyt1vx">
#         <div class="_3zfyse">
#          <h2 class="_1DYSFX">
#           Browsing Laptops
#          </h2>
#         </div>
#         <div class="_1xCO19">
#          <a class="_2KpZ6l _3dESVI" href="/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&amp;collection-tab-name=Browsing&amp;wid=5.productCard.PMU_V2_5">
#           <span>
#            VIEW ALL
#           </span>
#          </a>
#         </div>
#        </div>
#        <div data-tracking-id="Browsing Laptops">
#         <div class="_3ZYowz _2CfYpZ">
#          <div class="mYI3GX">
#           <div class="_2hKRMr _2CfYpZ" style="width:1330px">
#            <div class="_37K3-p" style="-webkit-transform:translateX(0px);-moz-transform:translateX(0px);-o-transform:translateX(0px);-ms-transform:translateX(0px);transform:translateX(0px)">
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/lenovo-ideapad-s145-core-i3-10th-gen-8-gb-256-gb-ssd-windows-10-home-s145-15iil-laptop/p/itmf7175ec6310c1?pid=COMFRCSGNVDZS5TT&amp;lid=LSTCOMFRCSGNVDZS5TT9PXBVF&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFRCSGNVDZS5TT&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_1_5.productCard.PMU_V2_Lenovo%2BIdeapad%2BS145%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25288%2BGB%252F256%2BGB%2BSSD%252FWindows%2B10%2BHome%2529%2BS145-15IIL%2BLaptop_laptops-store_COMFRCSGNVDZS5TT_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_1_NA_view-all&amp;cid=COMFRCSGNVDZS5TT" rel="noopener noreferrer" target="_blank" title="Lenovo Ideapad S145 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) S145-15IIL Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="Lenovo Ideapad S145 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) S145-15IIL Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/lenovo-ideapad-s145-core-i3-10th-gen-8-gb-256-gb-ssd-windows-10-home-s145-15iil-laptop/p/itmf7175ec6310c1?pid=COMFRCSGNVDZS5TT&amp;lid=LSTCOMFRCSGNVDZS5TT9PXBVF&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFRCSGNVDZS5TT&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_1_5.productCard.PMU_V2_Lenovo%2BIdeapad%2BS145%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25288%2BGB%252F256%2BGB%2BSSD%252FWindows%2B10%2BHome%2529%2BS145-15IIL%2BLaptop_laptops-store_COMFRCSGNVDZS5TT_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_1_NA_view-all&amp;cid=COMFRCSGNVDZS5TT" rel="noopener noreferrer" target="_blank" title="Lenovo Ideapad S145 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) S145-15IIL Laptop">
#                   Lenovo Ideapad S145 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 1...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFRCSGNVDZS5TT9PXBVF_COMFRCSGNVDZS5TT_">
#                   <div class="_3LWZlK">
#                    4
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (408)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹36,490
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    51,190
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     28% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                   <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                   </path>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/lenovo-ideapad-s145-core-i3-10th-gen-4-gb-256-gb-ssd-windows-10-home-s145-15iil-thin-light-laptop/p/itm92e3df60b52de?pid=COMFZX8YPEANZ2SM&amp;lid=LSTCOMFZX8YPEANZ2SMHSYEUI&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFZX8YPEANZ2SM&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_2_5.productCard.PMU_V2_Lenovo%2BIdeapad%2BS145%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25284%2BGB%252F256%2BGB%2BSSD%252FWindows%2B10%2BHome%2529%2BS145-15IIL%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFZX8YPEANZ2SM_neo%2Fmerchandising_1&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_2_NA_view-all&amp;cid=COMFZX8YPEANZ2SM" rel="noopener noreferrer" target="_blank" title="Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) S145-15IIL Thin and Light Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) S145-15IIL Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/lenovo-ideapad-s145-core-i3-10th-gen-4-gb-256-gb-ssd-windows-10-home-s145-15iil-thin-light-laptop/p/itm92e3df60b52de?pid=COMFZX8YPEANZ2SM&amp;lid=LSTCOMFZX8YPEANZ2SMHSYEUI&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFZX8YPEANZ2SM&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_2_5.productCard.PMU_V2_Lenovo%2BIdeapad%2BS145%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25284%2BGB%252F256%2BGB%2BSSD%252FWindows%2B10%2BHome%2529%2BS145-15IIL%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFZX8YPEANZ2SM_neo%2Fmerchandising_1&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_2_NA_view-all&amp;cid=COMFZX8YPEANZ2SM" rel="noopener noreferrer" target="_blank" title="Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) S145-15IIL Thin and Light Laptop">
#                   Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 1...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFZX8YPEANZ2SMHSYEUI_COMFZX8YPEANZ2SM_">
#                   <div class="_3LWZlK">
#                    4.1
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (527)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹33,990
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    51,890
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     34% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                   <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                   </path>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/acer-one-14-pentium-gold-4-gb-1-tb-hdd-windows-10-home-z2-485-thin-light-laptop/p/itm7b6d6b88ad576?pid=COMFUR8XH6ZS995D&amp;lid=LSTCOMFUR8XH6ZS995DD5INS8&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFUR8XH6ZS995D&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_3_5.productCard.PMU_V2_acer%2BOne%2B14%2BPentium%2BGold%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2BZ2-485%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFUR8XH6ZS995D_neo%2Fmerchandising_2&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_3_NA_view-all&amp;cid=COMFUR8XH6ZS995D" rel="noopener noreferrer" target="_blank" title="acer One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 10 Home) Z2-485 Thin and Light Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="acer One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 10 Home) Z2-485 Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/acer-one-14-pentium-gold-4-gb-1-tb-hdd-windows-10-home-z2-485-thin-light-laptop/p/itm7b6d6b88ad576?pid=COMFUR8XH6ZS995D&amp;lid=LSTCOMFUR8XH6ZS995DD5INS8&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFUR8XH6ZS995D&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_3_5.productCard.PMU_V2_acer%2BOne%2B14%2BPentium%2BGold%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2BZ2-485%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFUR8XH6ZS995D_neo%2Fmerchandising_2&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_3_NA_view-all&amp;cid=COMFUR8XH6ZS995D" rel="noopener noreferrer" target="_blank" title="acer One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 10 Home) Z2-485 Thin and Light Laptop">
#                   acer One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 10 Home) Z2-485...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFUR8XH6ZS995DD5INS8_COMFUR8XH6ZS995D_">
#                   <div class="_3LWZlK">
#                    4
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (8,447)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹22,990
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    37,500
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     38% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                   <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                   </path>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/hp-15s-dual-core-3020e-4-gb-1-tb-hdd-windows-10-home-15s-gy0003au-thin-light-laptop/p/itm4b0ea73088120?pid=COMFZ2MUDVF73GDA&amp;lid=LSTCOMFZ2MUDVF73GDAN0GJ2H&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFZ2MUDVF73GDA&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_4_5.productCard.PMU_V2_HP%2B15s%2BDual%2BCore%2B3020e%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2B15s-GY0003AU%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFZ2MUDVF73GDA_neo%2Fmerchandising_3&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_4_NA_view-all&amp;cid=COMFZ2MUDVF73GDA" rel="noopener noreferrer" target="_blank" title="HP 15s Dual Core 3020e - (4 GB/1 TB HDD/Windows 10 Home) 15s-GY0003AU Thin and Light Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="HP 15s Dual Core 3020e - (4 GB/1 TB HDD/Windows 10 Home) 15s-GY0003AU Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/hp-15s-dual-core-3020e-4-gb-1-tb-hdd-windows-10-home-15s-gy0003au-thin-light-laptop/p/itm4b0ea73088120?pid=COMFZ2MUDVF73GDA&amp;lid=LSTCOMFZ2MUDVF73GDAN0GJ2H&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFZ2MUDVF73GDA&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_4_5.productCard.PMU_V2_HP%2B15s%2BDual%2BCore%2B3020e%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2B15s-GY0003AU%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFZ2MUDVF73GDA_neo%2Fmerchandising_3&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_4_NA_view-all&amp;cid=COMFZ2MUDVF73GDA" rel="noopener noreferrer" target="_blank" title="HP 15s Dual Core 3020e - (4 GB/1 TB HDD/Windows 10 Home) 15s-GY0003AU Thin and Light Laptop">
#                   HP 15s Dual Core 3020e - (4 GB/1 TB HDD/Windows 10 Home) 15s-GY00...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFZ2MUDVF73GDAN0GJ2H_COMFZ2MUDVF73GDA_">
#                   <div class="_3LWZlK">
#                    3.9
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (157)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹23,990
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    24,784
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     3% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                   <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                   </path>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/dell-vostro-core-i3-10th-gen-8-gb-1-tb-hdd-windows-10-home-3401-thin-light-laptop/p/itm0b45b63fac02d?pid=COMFYZC5Y4GZYEWN&amp;lid=LSTCOMFYZC5Y4GZYEWNAE8BRJ&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFYZC5Y4GZYEWN&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_5_5.productCard.PMU_V2_DELL%2BVostro%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25288%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2BVostro%2B3401%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFYZC5Y4GZYEWN_neo%2Fmerchandising_4&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_5_NA_view-all&amp;cid=COMFYZC5Y4GZYEWN" rel="noopener noreferrer" target="_blank" title="DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/dell-vostro-core-i3-10th-gen-8-gb-1-tb-hdd-windows-10-home-3401-thin-light-laptop/p/itm0b45b63fac02d?pid=COMFYZC5Y4GZYEWN&amp;lid=LSTCOMFYZC5Y4GZYEWNAE8BRJ&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFYZC5Y4GZYEWN&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_5_5.productCard.PMU_V2_DELL%2BVostro%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25288%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2BVostro%2B3401%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFYZC5Y4GZYEWN_neo%2Fmerchandising_4&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_5_NA_view-all&amp;cid=COMFYZC5Y4GZYEWN" rel="noopener noreferrer" target="_blank" title="DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop">
#                   DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vo...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFYZC5Y4GZYEWNAE8BRJ_COMFYZC5Y4GZYEWN_">
#                   <div class="_3LWZlK">
#                    4
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (315)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹38,350
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    39,610
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     3% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                   <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                   </path>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/hp-15-ryzen-3-dual-core-3200u-4-gb-1-tb-hdd-windows-10-home-15-db-1059au-laptop/p/itmad2080fe450c4?pid=COMFSKF9QBHQCVEW&amp;lid=LSTCOMFSKF9QBHQCVEW23WF6S&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFSKF9QBHQCVEW&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_6_5.productCard.PMU_V2_HP%2B15%2BRyzen%2B3%2BDual%2BCore%2B3200U%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2B15-db%2B1059AU%2BLaptop_laptops-store_COMFSKF9QBHQCVEW_neo%2Fmerchandising_5&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_6_NA_view-all&amp;cid=COMFSKF9QBHQCVEW" rel="noopener noreferrer" target="_blank" title="HP 15 Ryzen 3 Dual Core 3200U - (4 GB/1 TB HDD/Windows 10 Home) 15-db 1059AU Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="HP 15 Ryzen 3 Dual Core 3200U - (4 GB/1 TB HDD/Windows 10 Home) 15-db 1059AU Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/hp-15-ryzen-3-dual-core-3200u-4-gb-1-tb-hdd-windows-10-home-15-db-1059au-laptop/p/itmad2080fe450c4?pid=COMFSKF9QBHQCVEW&amp;lid=LSTCOMFSKF9QBHQCVEW23WF6S&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_5_L2T2KA935QIP_MC.COMFSKF9QBHQCVEW&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Browsing%2BLaptops_6_5.productCard.PMU_V2_HP%2B15%2BRyzen%2B3%2BDual%2BCore%2B3200U%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FWindows%2B10%2BHome%2529%2B15-db%2B1059AU%2BLaptop_laptops-store_COMFSKF9QBHQCVEW_neo%2Fmerchandising_5&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Browsing%2BLaptops_LIST_productCard_cc_6_NA_view-all&amp;cid=COMFSKF9QBHQCVEW" rel="noopener noreferrer" target="_blank" title="HP 15 Ryzen 3 Dual Core 3200U - (4 GB/1 TB HDD/Windows 10 Home) 15-db 1059AU Laptop">
#                   HP 15 Ryzen 3 Dual Core 3200U - (4 GB/1 TB HDD/Windows 10 Home) 1...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFSKF9QBHQCVEW23WF6S_COMFSKF9QBHQCVEW_">
#                   <div class="_3LWZlK">
#                    4
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (791)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹31,490
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    33,256
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     5% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                   <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                   </path>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="_35l9rN rek5UH _1tKnHb">
#            <div class="_2kgArB _3y7w9p">
#             <svg class="" height="24" viewbox="0 0 16 27" width="14.6" xmlns="http://www.w3.org/2000/svg">
#              <path class="_23HYg_" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#              </path>
#             </svg>
#            </div>
#           </div>
#           <div class="_35l9rN _31Mq1b">
#            <div class="_2kgArB _2CP_Bu">
#             <svg class="_1xtBwk" height="24" viewbox="0 0 16 27" width="14.6" xmlns="http://www.w3.org/2000/svg">
#              <path class="_23HYg_" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#              </path>
#             </svg>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="_1AtVbE col-12-12">
#       <div class="_3E8aIl Zic51i">
#        <div class="Nyt1vx">
#         <div class="_3zfyse">
#          <h2 class="_1DYSFX">
#           Performance Laptops
#          </h2>
#         </div>
#         <div class="_1xCO19">
#          <a class="_2KpZ6l _3dESVI" href="/laptops/~cs-kfthfhsblc/pr?sid=6bo%2Cb5g&amp;collection-tab-name=Performance&amp;wid=6.productCard.PMU_V2_6">
#           <span>
#            VIEW ALL
#           </span>
#          </a>
#         </div>
#        </div>
#        <div data-tracking-id="Performance Laptops">
#         <div class="_3ZYowz _2CfYpZ">
#          <div class="mYI3GX">
#           <div class="_2hKRMr _2CfYpZ" style="width:1330px">
#            <div class="_37K3-p" style="-webkit-transform:translateX(0px);-moz-transform:translateX(0px);-o-transform:translateX(0px);-ms-transform:translateX(0px);transform:translateX(0px)">
#             <div class="_3YgSsQ" style="width:220px">
#              <div class="_2n7i6c">
#               <div class="_4ddWXP _3BCh3_">
#                <a class="_2rpwqI" href="/asus-vivobook-ultra-14-core-i3-11th-gen-8-gb-512-gb-ssd-windows-10-home-x413ea-eb323ts-thin-light-laptop/p/itma2dd35a76ad30?pid=COMFZ3VNCZNHDQ52&amp;lid=LSTCOMFZ3VNCZNHDQ52HMABRA&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_6_V3IOH8JM5DOO_MC.COMFZ3VNCZNHDQ52&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Performance%2BLaptops_1_6.productCard.PMU_V2_ASUS%2BVivoBook%2BUltra%2B14%2BCore%2Bi3%2B11th%2BGen%2B-%2B%25288%2BGB%252F512%2BGB%2BSSD%252FWindows%2B10%2BHome%2529%2BX413EA-EB323TS%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFZ3VNCZNHDQ52_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Performance%2BLaptops_LIST_productCard_cc_1_NA_view-all&amp;cid=COMFZ3VNCZNHDQ52" rel="noopener noreferrer" target="_blank" title="ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) X413EA-EB323TS Thin and Light Laptop">
#                 <div class="_28_T72">
#                  <div>
#                   <div class="CXW8mj" style="height:150px;width:150px">
#                    <img alt="ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) X413EA-EB323TS Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#                <div>
#                 <div>
#                  <a class="s1Q9rs" href="/asus-vivobook-ultra-14-core-i3-11th-gen-8-gb-512-gb-ssd-windows-10-home-x413ea-eb323ts-thin-light-laptop/p/itma2dd35a76ad30?pid=COMFZ3VNCZNHDQ52&amp;lid=LSTCOMFZ3VNCZNHDQ52HMABRA&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_fa5534e3-0725-4086-828a-13bdfa022ce7_6_V3IOH8JM5DOO_MC.COMFZ3VNCZNHDQ52&amp;ppt=None&amp;ppn=None&amp;ssid=okksx3nvlc0000001618559828642&amp;otracker=clp_pmu_v2_Performance%2BLaptops_1_6.productCard.PMU_V2_ASUS%2BVivoBook%2BUltra%2B14%2BCore%2Bi3%2B11th%2BGen%2B-%2B%25288%2BGB%252F512%2BGB%2BSSD%252FWindows%2B10%2BHome%2529%2BX413EA-EB323TS%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMFZ3VNCZNHDQ52_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Performance%2BLaptops_LIST_productCard_cc_1_NA_view-all&amp;cid=COMFZ3VNCZNHDQ52" rel="noopener noreferrer" target="_blank" title="ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) X413EA-EB323TS Thin and Light Laptop">
#                   ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 GB/512 GB SSD/Window...
#                  </a>
#                 </div>
#                 <div class="gUuXy- _2D5lwg">
#                  <span class="_1lRcqv" id="productRating_LSTCOMFZ3VNCZNHDQ52HMABRA_COMFZ3VNCZNHDQ52_">
#                   <div class="_3LWZlK">
#                    4.3
#                    <img class="_1wB99o" src="..."/>
#                   </div>
#                  </span>
#                  <span class="_2_R_DZ">
#                   (31)
#                  </span>
#                 </div>
#                 <div class="_8VNy32">
#                  <div class="_25b18c">
#                   <div class="_30jeq3">
#                    ₹40,990
#                   </div>
#                   <div class="_3I9_wc">
#                    ₹
#                    <!-- -->
#                    46,390
#                   </div>
#                   <div class="_3Ay6Sb">
#                    <span>
#                     11% off
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="_2hVSre _1eAP-x">
#                 <div class="_36FSn5">
#                  <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
# ...
#             Best Laptops Under RS. 50,000
#            </a>
#            <span>
#            </span>
#            <span>
#             |
#            </span>
#            <span>
#            </span>
#            <a href="/laptops/~laptops-under-rs60000/pr?sid=6bo,b5g" title="best laptops under 60000">
#             Best Laptops Under RS. 60,000
#            </a>
#            <span>
#            </span>
#            <span>
#             |
#            </span>
#            <span>
#            </span>
#            <a href="/laptops/~laptops-under-rs70000/pr?sid=6bo,b5g" title="best laptops under 70000">
#             Best Laptops Under RS. 70,000
#            </a>
#           </p>
#           <p>
#            <br/>
#           </p>
#           <p>
#            <br/>
#           </p>
#           <p>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div class="_2WErco row">
#         <div class="_2Brcj4">
#          <div class="_3-dnWo">
#           ABOUT
#          </div>
#          <a class="_1arVWX" href="/helpcentre?otracker=undefined_footer_navlinks">
#           Contact Us
#          </a>
#          <a class="_1arVWX" href="/about-us?otracker=undefined_footer_navlinks">
#           About Us
#          </a>
#          <a class="_1arVWX" href="https://www.flipkartcareers.com/?otracker=undefined_footer_navlinks">
#           Careers
#          </a>
#          <a class="_1arVWX" href="http://stories.flipkart.com/?otracker=undefined_footer_navlinks">
#           Flipkart Stories
#          </a>
#          <a class="_1arVWX" href="/s/press?otracker=undefined_footer_navlinks">
#           Press
#          </a>
#          <a class="_1arVWX" href="https://www.flipkartwholesale.com/?otracker=undefined_footer_navlinks" target="_blank">
#           Flipkart Wholesale
#          </a>
#         </div>
#         <div class="_2Brcj4">
#          <div class="_3-dnWo">
#           HELP
#          </div>
#          <a class="_1arVWX" href="/pages/payments">
#           Payments
#          </a>
#          <a class="_1arVWX" href="/pages/shipping">
#           Shipping
#          </a>
#          <a class="_1arVWX" href="/helpcentre?catalog=55c9c6edb000002e002c1701&amp;view=CATALOG">
#           Cancellation &amp; Returns
#          </a>
#          <a class="_1arVWX" href="/helpcentre?catalog=55c9c8e2b0000023002c1702&amp;view=CATALOG">
#           FAQ
#          </a>
#          <a class="_1arVWX" href="https://seller.flipkart.com/fiv?otracker=undefined_footer_navlinks">
#           Report Infringement
#          </a>
#         </div>
#         <div class="_2Brcj4">
#          <div class="_3-dnWo">
#           POLICY
#          </div>
#          <a class="_1arVWX" href="/pages/returnpolicy?otracker=undefined_footer_navlinks">
#           Return Policy
#          </a>
#          <a class="_1arVWX" href="/pages/terms?otracker=undefined_footer_navlinks">
#           Terms Of Use
#          </a>
#          <a class="_1arVWX" href="/pages/paymentsecurity?otracker=undefined_footer_navlinks">
#           Security
#          </a>
#          <a class="_1arVWX" href="/pages/privacypolicy?otracker=undefined_footer_navlinks">
#           Privacy
#          </a>
#          <a class="_1arVWX" href="/sitemap?otracker=undefined_footer_navlinks">
#           Sitemap
#          </a>
#          <a class="_1arVWX" href="/pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks">
#           EPR Compliance
#          </a>
#         </div>
#         <div class="_2Brcj4">
#          <div class="_3-dnWo">
#           SOCIAL
#          </div>
#          <a class="_1arVWX" href="https://www.facebook.com/flipkart">
#           Facebook
#          </a>
#          <a class="_1arVWX" href="https://www.twitter.com/flipkart">
#           Twitter
#          </a>
#          <a class="_1arVWX" href="https://www.youtube.com/flipkart">
#           YouTube
#          </a>
#         </div>
#         <div class="_2Brcj4 address">
#          <div class="_3JHi0r">
#           <div class="_3-dnWo">
#            <span>
#             Mail Us:
#            </span>
#           </div>
#           <div class="_1U1qnR">
#            <div class="_1LJS6T">
#             <div class="_2NKhZn _1U1qnR">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
#              <p>
#               Clove Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Bengaluru, 560103,
#              </p>
#              <p>
#               Karnataka, India
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="_2Brcj4 address">
#          <div class="_3IT4e6">
#           <div class="_3-dnWo">
#            <span>
#             Registered Office Address:
#            </span>
#           </div>
#           <div class="_1U1qnR">
#            <div class="_1LJS6T">
#             <div class="_2NKhZn _1U1qnR">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
#              <p>
#               Clove Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Bengaluru, 560103,
#              </p>
#              <p>
#               Karnataka, India
#              </p>
#              <p>
#               CIN : U51109KA2012PTC066107
#              </p>
#              <p>
#               Telephone:
#               <a href="tel:18002029898">
#                1800 202 9898
#               </a>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div>
#         <div class="_2uz0vJ">
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect">
#            <span class="hDTmm5">
#             Sell On Flipkart
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="https://brands.flipkart.com">
#            <span class="hDTmm5">
#             Advertise
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="/the-gift-card-store?otracker=undefined_footer_footer_navlinks">
#            <span class="hDTmm5">
#             Gift Cards
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="/helpcentre?otracker=undefined_footer_footer_navlinks">
#            <span class="hDTmm5">
#             Help Center
#            </span>
#           </a>
#          </div>
#          <span class="z3ht-w">
#           © 2007-
#           <!-- -->
#           2021
#           <!-- -->
#           <span>
#            Flipkart.com
#           </span>
#          </span>
#          <img src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/payment-method_7934bc.svg"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="_1EcK2J _38JCdA">
#      <div class="bra6U8">
#       <svg class="_2TdLiZ" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#        <path class="_3ZKfA2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#        </path>
#       </svg>
#       <span>
#        Back to top
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script nonce="5691071682612875426" type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }
#   </script>
#   <script id="is_script" nonce="5691071682612875426">
#    window.__INITIAL_STATE__ = {"abExperiments":{},"activateVip":{"asyncStatus":"INIT","widget":[]},"autosuggest":{"query":null,"payloadId":null,"searchHistory":[],"asyncStatus":"INIT","words":{},"searchBrowseHistoryRequest":{}},"basket":{"asyncStatus":"INIT","pageLevelError":false},"buyingGuides":{},"cartData":{"asyncStatus":"INIT","pageLevelError":false},"saveForLaterData":{"asyncStatus":"INIT","data":{"requestedStores":[]}},"checkoutPage":{"summary":{"asyncStatus":"INIT"},"checkoutAsyncStatus":"INIT","addressCache":{"newAddressForm":{"id":"newAddressForm","name":"","addressLine1":"","addressLine2":"","landmark":"","city":"","state":"","pincode":"","phone":"","alternatePhone":"","locationTypeTag":""}},"visualState":{"login":"EXPANDED","address":"COLLAPSED","orderSummary":"COLLAPSED","payment":"COLLAPSED"},"loginState":{"asyncStatus":"INIT"},"buyNow":{"eids":"","domain":"physical","analytics":{},"quantity":0},"addressLocation":{"asyncStatus":"INIT"},"staticPage":{"asyncStatus":"INIT"}},"claimedReward":{"asyncStatus":"INIT","widget":[]},"compareAddProductData":{"asyncStatus":"INIT","brandvsproduct":{},"brand":null},"compareBrandData":{"asyncStatus":"INIT"},"comparePageData":{"asyncStatus":"INIT","showDifference":false},"compareWidgetData":[],"config":{"0":"R","1":"e","2":"q","3":"u","4":"e","5":"s","6":"t","7":" ","8":"t","9":"i","10":"m","11":"e","12":"o","13":"u","14":"t","15":":","16":" ","17":"G","18":"E","19":"T","20":"_","21":"C","22":"O","23":"N","24":"F","25":"I","26":"G","27":"_","28":"R","29":"E","30":"Q","31":"U","32":"E","33":"S","34":"T","asyncStatus":"ERROR","data":{"tooltip-zion-services":{"deliveryCharge":"## Shipping Charges For Non Flipkart Assured Items\n\n Shipping charges are calculated based on the number of units, distance and delivery date.\n\n For Plus as well as Non-Plus customers, Seller will decide shipping charges for all non-FAssured items.","deliverdBy":"## Shipping Charges For Flipkart Assured Items\n\n Shipping charges are calculated based on the number of units, distance and delivery date. \n\n For Plus customers, shipping charges are free.\n\n For non-Plus customers, if the total value of FAssured items is more than Rs.500, shipping charges are free.  If the total value of FAssured items is less than Rs.500, shipping charges = Rs.40 per unit\n\n\\* For faster delivery, shipping charges will be applicable","tentativeRelease":"__What is the tentative delivery time?__\n\n Sellers generally procure and ship the items within the time specified on the product page. Business days exclude public holidays and Sundays.\n\n Estimated delivery time depends on the following factors:\n * The Seller offering the product \n * Product's availability with the Seller \n * The destination to which you want the order shipped to and the Seller's location\n\n__Why does the delivery date not correspond to the delivery timeline of X-Y business days?__ \n\n It is possible that the Seller or our courier partners observe a holiday between the day you placed your order and the date of delivery, which is based on the timelines shown on the product page. In this case, we add a day to the estimated date. Some courier partners and Sellers do not work on Sundays and this is factored in to the delivery dates. \n\n __Why does the estimated delivery time vary for each seller?__ \n\n You have probably noticed varying estimated delivery times for Sellers of the product you are interested in. Delivery times are influenced by product availability, geographic location of the Seller, your shipping destination and the courier partner's time-to-deliver to your location. \n\n Please enter your default pin code on the product page (you don't have to enter it every single time) to know more accurate delivery times on the product page itself. \n\n __Seller does not/cannot ship to my area. Why?__ \n\n Enter your pincode on the product page (you don't have to enter it every single time) to know whether the product can be delivered to your loca ...
#   </script>
#   <script nonce="5691071682612875426">
#    window.__BUNDLE_IDS__ = {"children":[{"id":"navMenu"}]};
#   </script>
#   <script nonce="5691071682612875426">
#    window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;
#   </script>
#   <script nonce="5691071682612875426">
#    if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }
#   </script>
#   <script nonce="5691071682612875426" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/raven.3.22.3.js">
#   </script>
#   <script nonce="5691071682612875426">
#    window.Raven && window.Raven.config('https://b2fe488e344a47eda53b8d306edec9b7@sentry.flipkart.com/2',{
# 		release: '4.32.0',
# 		whitelistUrls: [
# 			/flipkart\.com/,
# 			/flixcart\.com/
# 		],
# 		ignoreErrors: [
# 			// Random plugins/extensions
# 			'top.GLOBALS',
# 			// See: http://blog.errorception.com/2012/03/tale-of-unfindable-js-error.html
# 			'originalCreateNotification',
# 			'canvas.contentDocument',
# 			'MyApp_RemoveAllHighlights',
# 			'atomicFindClose',
# 			// Facebook borked
# 			'fb_xd_fragment',
# 			// ISP "optimizing" proxy - `Cache-Control: no-transform` seems to reduce this. (thanks @acdha)
# 			// See http://stackoverflow.com/questions/4113268/how-to-stop-javascript-injection-from-vodafone-proxy
# 			'bmi_SafeAddOnload',
# 			'EBCallBackMessageReceived',
# 			'failed to fetch'
# 		],
# 		ignoreUrls: [
# 			// Facebook flakiness
# 			/graph\.facebook\.com/i,
# 			// Facebook blocked
# 			/connect\.facebook\.net\/en_US\/all\.js/i,
# 			// Chrome extensions
# 			/extensions\//i,
# 			/^chrome:\/\//i
# 		],
# 		sanitizeKeys: ['nsid', 'secureToken', 'SN'],
# 		environment: 'production',
# 		sampleRate: 0.5
# 	}).install();
# 	window.Raven && window.Raven.setUserContext({
# 		accountId: ''
# 	});
#   </script>
#   <script async="" defer="defer" id="omni_script" nonce="5691071682612875426" src="//static-assets-web.flixcart.com/www/linchpin/batman-returns/omni/omni16.js">
#   </script>
#   <script nonce="5691071682612875426">
#    window._pxAppId = 'PXgNtTli3A';
#   </script>
#   <script async="" nonce="5691071682612875426" src="//static-assets-web.flixcart.com/px/gNtTli3A/init.js">
#   </script>
#  </body>
# </html>

# %%
desc = soup.find_all('div',class_='CXW8mj')
descriptions = []
for i in range(len(desc)):
    descriptions.append(desc[i].text) # We can even access the child tags with dot access.
descriptions
len(descriptions)
# Out:
# 30

# %%
desc
# Out:
# [<div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Ideapad S145 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) S145-15IIL Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Ideapad S145 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) S145-15IIL Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="acer One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 10 Home) Z2-485 Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="HP 15s Dual Core 3020e - (4 GB/1 TB HDD/Windows 10 Home) 15s-GY0003AU Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="HP 15 Ryzen 3 Dual Core 3200U - (4 GB/1 TB HDD/Windows 10 Home) 15-db 1059AU Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) X413EA-EB323TS Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="ASUS VivoBook 14 Ryzen 5 Hexa Core 4500U - (8 GB/512 GB SSD/Windows 10 Home) M413IA-EK581T Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="DELL Vostro 3405 Ryzen 5 Quad Core 3450U - (8 GB/256 GB SSD/Windows 10 Home) Vostro 3405 Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Ideapad 3 Core i5 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) 15IIL05 Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Mi Notebook 14 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) JYU4243IN Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="msi Modern 14 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) Modern 14 B10MW-423IN Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Ideapad S 540 Core i5 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/2 GB Graphics) 540-15IML Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="MICROSOFT Surface Pro 7 Core i5 10th Gen - (8 GB/128 GB SSD/Windows 10 Home) 1866 2 in 1 Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="HP Pavilion x360 Core i7 8th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/2 GB Graphics) 14-dh0112TX 2 in 1 Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) X413EP-EB513TS Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Mi Notebook Horizon Edition 14 Core i7 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) JYU4246IN Thin and Light Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="msi Prestige 15 Core i7 11th Gen - (16 GB/512 GB SSD/Windows 10 Home/4 GB Graphics) Prestige 15 A11SCX-273IN Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="acer Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650) A715-42G Gaming Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="msi GF63 Thin Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650 Max-Q) GF63 Thin 9SCXR-418IN Gaming Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Legion 5 Ryzen 5 Hexa Core 4600H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650/120 HZ) 5 15ARH05 Gaming Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650 Ti) A715-41G-R7YZ Gaming Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Legion Y540 Core i5 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650/60 Hz) Y540-15IRH-PG0 Gaming Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650 Ti) A715-75G-51H8 Gaming Laptop" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div style="-webkit-filter:grayscale(1);-moz-filter:grayscale(1);-o-filter:grayscale(1);-ms-filter:grayscale(1);filter:grayscale(1);opacity:0.6"><div class="CXW8mj" style="height:150px;width:150px"><img alt="Lenovo Core i3 (9100) (4 GB RAM/Intel UHD Graphics 630 Graphics/1 TB Hard Disk/Windows 10 (64-bit)) Full Tower with MS Office" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Electrobot Core 2 Duo (4 GB RAM/Intel Onboard Graphics Graphics/160 GB Hard Disk/Windows 7 Ultimate) Mid Tower" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Electrobot Intel Core I5 650 (8 GB RAM/Integrated Graphics Graphics/1 TB Hard Disk/120 GB SSD Capacity/Free DOS/2 GB Graphics Memory) Mini Tower" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Electrobot Core 2 Duo (4 GB RAM/Intel Onboard Graphics Graphics/500 GB Hard Disk/Windows 7 Ultimate) Full Tower" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div><div class="CXW8mj" style="height:150px;width:150px"><img alt="Electrobot Core 2 Duo (4 GB RAM/Intel Onboard Graphic Graphics/320 GB Hard Disk/Windows 7 Ultimate) Mid Tower" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>,
#  <div class="_28_T72"><div style="-webkit-filter:grayscale(1);-moz-filter:grayscale(1);-o-filter:grayscale(1);-ms-filter:grayscale(1);filter:grayscale(1);opacity:0.6"><div class="CXW8mj" style="height:150px;width:150px"><img alt="HP Core i3 (10th Gen) (8 GB DDR4/1 TB/Windows 10 Home/21.5 Inch Screen/22-df0141in) with MS Office" class="_396cs4" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_fcebae.svg"/></div></div></div>]

# %%
descriptions
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
commonclass = soup.find_all('img',class_='_396cs4 _3exPp9') # We observe that the classnames for the different specifications are under one div.So

# %%
processors=[]
ram=[]
os=[]
storage=[]
inches=[]
warranty=[]

# %%
for i in range(0,len(commonclass)):
    p=commonclass[i].text # Extracting the text from the tags
    if("Core" in p): 
        processors.append(p)
    elif("RAM" in p): # If RAM is present in the text then append it to the ram list. Similarly do this for the other features as well
        ram.append(p)
    elif("HDD" in p or "SSD" in p):
        storage.append(p)
    elif("Operating" in p):
        os.append(p)
    elif("Display" in p):
        inches.append(p)
    elif("Warranty" in p):
        warranty.append(p)

# %%
print(len(processors))
print(len(warranty))
print(len(os))
print(len(ram))
print(len(inches))
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
price = soup.find_all('div',class_='_30jeq3') # Extracting price of each laptop from the website
prices = []
for i in range(len(price)):
    prices.append(price[i].text)
prices
len(prices)
# Out:
# 30

# %%
prices
# Out:
# ['₹36,490',
#  '₹33,990',
#  '₹22,990',
#  '₹23,990',
#  '₹38,350',
#  '₹31,490',
#  '₹40,990',
#  '₹49,990',
#  '₹42,499',
#  '₹43,990',
#  '₹44,999',
#  '₹51,990',
#  '₹60,890',
#  '₹78,990',
#  '₹76,990',
#  '₹62,990',
#  '₹59,999',
#  '₹1,16,990',
#  '₹55,990',
#  '₹54,990',
#  '₹66,990',
#  '₹50,990',
#  '₹60,990',
#  '₹54,990',
#  '₹23,990',
#  '₹5,800',
#  '₹15,000',
#  '₹7,000',
#  '₹6,250',
#  '₹40,990']

# %%
original_price = soup.find_all('div',class_='_2hVSre _1eAP-x')
len(original_price)
# Out:
# 30

# %%
original_prices = []
for i in range(len(original_price)):
    original_prices.append(original_price[i].text)
original_prices
len(original_prices)
# Out:
# 30

# %%
rating = soup.find_all('div',class_='_3LWZlK') # Extracting the ratings of all the laptops
ratings = []
for i in range(len(rating)):
    ratings.append(rating[i].text)
ratings
len(ratings)
# Out:
# 30

# %%
ratings
# Out:
# ['4',
#  '4.1',
#  '4',
#  '3.9',
#  '4',
#  '4',
#  '4.3',
#  '4.5',
#  '4.2',
#  '4',
#  '4.3',
#  '4.1',
#  '4.5',
#  '4.3',
#  '4.6',
#  '4.4',
#  '4.4',
#  '4.8',
#  '4.5',
#  '4.5',
#  '4.6',
#  '4.4',
#  '4.6',
#  '4.4',
#  '4.3',
#  '3.6',
#  '3.7',
#  '3.4',
#  '3.6',
#  '4.2']

# %%
discount = soup.find_all('span')
discount
# Out:
# [<span>Cart</span>,
#  <span>Back to College Season, </span>,
#  <span>, </span>,
#  <span class="_28Go3e _2JsIUT"><div class="_1bEAQy" style="padding-top:28.76%;width:100%"><img alt="d" class="_2OHU_q"/><img alt="d" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/flap/50/50/image/220bee42dbd0ca51.jpg?q=50"/></div></span>,
#  <span>VIEW ALL</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFRCSGNVDZS5TT9PXBVF_COMFRCSGNVDZS5TT_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(408)</span>,
#  <span>28% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZX8YPEANZ2SMHSYEUI_COMFZX8YPEANZ2SM_"><div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(527)</span>,
#  <span>34% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFUR8XH6ZS995DD5INS8_COMFUR8XH6ZS995D_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(8,447)</span>,
#  <span>38% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZ2MUDVF73GDAN0GJ2H_COMFZ2MUDVF73GDA_"><div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(157)</span>,
#  <span>3% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFYZC5Y4GZYEWNAE8BRJ_COMFYZC5Y4GZYEWN_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(315)</span>,
#  <span>3% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFSKF9QBHQCVEW23WF6S_COMFSKF9QBHQCVEW_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(791)</span>,
#  <span>5% off</span>,
#  <span>VIEW ALL</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZ3VNCZNHDQ52HMABRA_COMFZ3VNCZNHDQ52_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(31)</span>,
#  <span>11% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFSKF9YYUGSHASOXHDYZ_COMFSKF9YYUGSHAS_"><div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(634)</span>,
#  <span>1% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFY7GFE7KZHDBG3HRWDJ_COMFY7GFE7KZHDBG_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(114)</span>,
#  <span>10% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZS9H3SWW5VAGQ4GCFS_COMFZS9H3SWW5VAG_"><div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(552)</span>,
#  <span>31% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFW48WY8YY7HYBOBWOYU_COMFW48WY8YY7HYB_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(2,498)</span>,
#  <span>15% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFYZC5CQG2CNKWWFHWGK_COMFYZC5CQG2CNKW_"><div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(9)</span>,
#  <span>9% off</span>,
#  <span>VIEW ALL</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZT5M2SR4M8KZFWT3O6_COMFZT5M2SR4M8KZ_"><div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(551)</span>,
#  <span>35% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZPBXP9FTJXPMIITYTE_COMFZPBXP9FTJXPM_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(53)</span>,
#  <span>15% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFSFNVSGVZZFCFMS9HAT_COMFSFNVSGVZZFCF_"><div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(511)</span>,
#  <span>18% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFWXWWNYVCKASKNXDWLT_COMFWXWWNYVCKASK_"><div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(95)</span>,
#  <span>21% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFZEYHZAYXNTDYPW5JGF_COMFZEYHZAYXNTDY_"><div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(52)</span>,
#  <span>9% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFYZC59JUZSEBRQMDA9Q_COMFYZC59JUZSEBR_"><div class="_3LWZlK">4.8<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(5)</span>,
#  <span>1% off</span>,
#  <span>VIEW ALL</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMGYCG8ZBXWPYUUYQDSM8_COMGYCG8ZBXWPYUU_"><div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(549)</span>,
#  <span>37% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFSFNWVD49FZ5FY2W8TY_COMFSFNWVD49FZ5F_"><div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(3,331)</span>,
#  <span>42% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMGY8Y5AV5W5YKGBNDOLF_COMGY8Y5AV5W5YKG_"><div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(84)</span>,
#  <span>24% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFVW9TGFYZZGFQWAXP94_COMFVW9TGFYZZGFQ_"><div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(343)</span>,
#  <span>11% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFXZZMWZGM4MPJSWHXIX_COMFXZZMWZGM4MPJ_"><div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(72)</span>,
#  <span>33% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCOMFR6AAYHTCDHTGRBZYBI_COMFR6AAYHTCDHTG_"><div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(1,047)</span>,
#  <span>35% off</span>,
#  <span>VIEW ALL</span>,
#  <span class="_192laR">Temporarily Unavailable</span>,
#  <span class="_1lRcqv" id="productRating_LSTCPUFS8YXU5BTHC5PO5XNAS_CPUFS8YXU5BTHC5P_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(409)</span>,
#  <span>25% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCPUF5CN2HQKWRQ4EKLBXKA_CPUF5CN2HQKWRQ4E_"><div class="_3LWZlK">3.6<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(243)</span>,
#  <span class="_1lRcqv" id="productRating_LSTCPUFVHGBRHBYAG6QLIK9KR_CPUFVHGBRHBYAG6Q_"><div class="_3LWZlK">3.7<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(195)</span>,
#  <span>25% off</span>,
#  <span class="_1lRcqv" id="productRating_LSTCPUF5CQ2PURZYPVF1Z1OKK_CPUF5CQ2PURZYPVF_"><div class="_3LWZlK">3.4<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(336)</span>,
#  <span class="_1lRcqv" id="productRating_LSTCPUF5CNXVXAZSF6GMMMFFR_CPUF5CNXVXAZSF6G_"><div class="_3LWZlK">3.6<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(288)</span>,
#  <span class="_192laR">Temporarily Unavailable</span>,
#  <span class="_1lRcqv" id="productRating_LSTAIOFVNEXEA6HZ5UCVTPKLB_AIOFVNEXEA6HZ5UC_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(156)</span>,
#  <span>4% off</span>,
#  <span><a href="/laptops/~notebook/pr?sid=6bo,b5g">notebook</a></span>,
#  <span><a href="/laptops/ultrabook~type/pr?sid=6bo,b5g">ultrabook</a></span>,
#  <span><a href="/laptops/netbook~type/pr?sid=6bo,b5g">netbook</a>,<a href="/laptops/~2-in-1-laptops/pr?sid=6bo,b5g">2 in one Laptops</a></span>,
#  <span><a href="/laptops/hp~brand/pr?sid=6bo,b5g">HP laptops</a></span>,
#  <span>Lenovo laptops</span>,
#  <span><a href="/laptops/acer~brand/pr?sid=6bo,b5g">Acer laptops</a></span>,
#  <span><a href="/laptops/apple~brand/pr?sid=6bo,b5g">Apple MacBooks</a></span>,
#  <span><a href="/laptops/asus~brand/pr?sid=6bo,b5g"> Asus Laptops</a></span>,
#  <span><b>Multitasking and Processing requirement can be fulfilled by choosing RAM from various option ranging from 2GB to 16GB.</b></span>,
#  <span>Laptops with and without touchscreen can also be chosen from. Other options include a Backlit keyboard, HD Webcam, Optical DVD drive, Number of USB ports, HDMI port availability and WLAN port availability.</span>,
#  <span>The best laptops to invest in</span>,
#  <span><b>Types of laptops based on application</b></span>,
#  <span><br/></span>,
#  <span>How to buy a gaming laptop?</span>,
#  <span><a href="/laptops/alienware~brand/pr?sid=6bo,b5g">Alienware</a></span>,
#  <span><a href="/laptops/msi~brand/pr?sid=6bo,b5g">MSI</a></span>,
#  <span>ii) Keep your Windows OS updated.</span>,
#  <span>iv) Check with a malware scanner if your PC is affected by some malware infection or rogue programs.</span>,
#  <span><br/></span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span> </span>,
#  <span>|</span>,
#  <span> </span>,
#  <span>Mail Us:</span>,
#  <span>Registered Office Address:</span>,
#  <span class="hDTmm5">Sell On Flipkart</span>,
#  <span class="hDTmm5">Advertise</span>,
#  <span class="hDTmm5">Gift Cards</span>,
#  <span class="hDTmm5">Help Center</span>,
#  <span class="z3ht-w">© 2007-<!-- -->2021<!-- --> <span>Flipkart.com</span></span>,
#  <span>Flipkart.com</span>,
#  <span>Back to top</span>]

# %%
discounts = []
for i in range(0,len(discount)):
    p=discount[i].text
    if("% off" in p): # Extracting the tags which contain the discount(all the discounts contain % off so checking with that condition we obtain all the laptops which have discounts)
        discounts.append(p)
discounts
len(discounts)
# Out:
# 27

# %%
discounts
# Out:
# ['28% off',
#  '34% off',
#  '38% off',
#  '3% off',
#  '3% off',
#  '5% off',
#  '11% off',
#  '1% off',
#  '10% off',
#  '31% off',
#  '15% off',
#  '9% off',
#  '35% off',
#  '15% off',
#  '18% off',
#  '21% off',
#  '9% off',
#  '1% off',
#  '37% off',
#  '42% off',
#  '24% off',
#  '11% off',
#  '33% off',
#  '35% off',
#  '25% off',
#  '25% off',
#  '4% off']

# %%
d={'Description':descriptions,
     'Processor':processors,
     'RAM':ram,
     'Operating System':os,
     'Storage':storage,
     'Display':inches,
     'Warranty':warranty,
     'Price':prices}

# %%
dataset = pd.DataFrame(data = d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-1119ea15d0c9> in <module>
# ----> 1 dataset = pd.DataFrame(data = d)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length
