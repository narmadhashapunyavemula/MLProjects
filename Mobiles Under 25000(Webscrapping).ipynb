# %% [markdown]
# # Project on Best Mobiles under 25000

# %% [markdown]
# The project  works with the help of Web Scrapping technique.From the website www.91mobiles.com The data's of best mobile phones comes under the range of 25000 as been shortlised.The Basic EDA process for the fetched datas had been done.

# %% [markdown]
# # Importing the libraries required for the EDA and Scrapping process

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Making request to get the required web address/URL to fetch the data

# %%
URL = 'https://www.91mobiles.com/top-10-mobiles-below-25000-in-india'
response = requests.get(URL)

# %% [markdown]
# # Checking the content of whole page

# %%
response.content
# Out:
# b'    <!DOCTYPE html>\n    <html>\n    <head>\n                            <script type="text/javascript">\n                (function () {\n                    var s = document.createElement(\'script\');\n                    s.type = \'text/javascript\';\n                    s.async = true;\n                    s.src = \'//ht-91mobiles.hoverr.media/js/tera_91mobiles.js\';\n                    var x = document.getElementsByTagName(\'script\')[0];\n                    x.parentNode.insertBefore(s, x);\n                })();\n            </script>\n                        <script type="text/javascript">\n            var menu_cat_id = 553;\n            var floating_menu = true;\n        </script>\n        <meta http-equiv="content-type" content="text/html;">\n<title>Best Mobile phones under Rs. 25,000 in India (21st April 2021) | 91mobiles.com</title>\n<META NAME="description" CONTENT="Looking for best mobile phones under Rs. 25,000 in India but confused? Get the list of top 10 phones online under your budget, equipped with good camera, battery and storage. You can also ask questions related to devices." />\n<META NAME="keywords" CONTENT="Best Phone under Rs. 25,000, top mobiles under Rs. 25,000." />\n<meta property="fb:pages" content="132814090096744" />\n<!-- <meta name="google-site-verification" content="" /> -->\n<meta name="google-site-verification" content="VJxqEyygt3C1CTUDiorRtHqGOgsubqBfI6KDSNKTruY" />\n<meta http-equiv="x-dns-prefetch-control" content="on">\n<link rel="dns-prefetch" href="//www.91-cdn.com">\n<link rel="dns-prefetch" href="//www.91-img.com">\n<link rel="dns-prefetch" href="//img.91mobiles.com">\n<link rel="dns-prefetch" href="//static.hub.91mobiles.com">\n<link rel="dns-prefetch" href="//dealsstatic.91mobiles.com">\n<link rel="dns-prefetch" href="//img.qna.91mobiles.com">\n<link rel="dns-prefetch" href="//feeds.img.91mobiles.com">\n<link rel="dns-prefetch" href="//img.youtube.com">\n<link rel="dns-prefetch" href="//api.91mobiles.com">\n<link rel="dns-prefetch" href="//shopengage.91mobiles.com">\n<link rel="dns-prefetch" href="//ajax.googleapis.com">\n<link rel="dns-prefetch" href="//fonts.googleapis.com">\n<link rel="dns-prefetch" href="//pubads.g.doubleclick.net">\n<link rel="dns-prefetch" href="//s3.amazonaws.com">\n<link rel="dns-prefetch" href="//connect.facebook.net">\n<link rel="dns-prefetch" href="//platform.twitter.com">\n<link rel="dns-prefetch" href="//bs.serving-sys.com">\n<link rel="dns-prefetch" href="//ad.doubleclick.net">\n<link rel="dns-prefetch" href="//stats.g.doubleclick.net">\n<link rel="dns-prefetch" href="//sb.scorecardresearch.com">\n<link rel="dns-prefetch" href="//www.googletagservices.com">\n<link rel="dns-prefetch" href="//adservice.google.co.in">\n<link rel="dns-prefetch" href="//adservice.google.com">\n<link rel="dns-prefetch" href="//securepubads.g.doubleclick.net">\n<link rel="dns-prefetch" href="//tags.crwdcntrl.net">\n<link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n<link rel="dns-prefetch" href="//www.facebook.com">\n<link rel="dns-prefetch" href="//cdn.ampproject.org">\n<link rel="dns-prefetch" href="//bcp.crwdcntrl.net">\n<link rel="dns-prefetch" href="//pagead2.googlesyndication.com"><link rel="canonical" href="https://www.91mobiles.com/top-10-mobiles-below-25000-in-india" />\n<link rel="alternate" href="android-app://com.mob91/https/www.91mobiles.com/top/product?ep=/app/page/product/list/435&tp=435&utm_source=google&utm_medium=organic&utm_campaign=app" />\n\t<link  rel="amphtml"  href="https://www.91mobiles.com/top-10-mobiles-below-25000-in-india-amp" />\n            <link  rel=\'alternate\' href="https://www.91mobiles.com/top-10-mobiles-below-25000-in-india" hreflang="en" />\n            <link  rel=\'alternate\' href="https://www.91mobiles.com/hi/top-10-mobiles-below-25000-in-india" hreflang="hi" />\n            <link  rel=\'alternate\' href="https://www.91mobiles.com/ta/top-10-mobiles-below-25000-in-india" hreflang="ta" />\n            <link  rel=\'altern ...

# %% [markdown]
# # Basic cleaning process of data

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %% [markdown]
# # Fetching the required value from the page

# %%
df = soup.find_all('div', class_= 'finder_snipet_wrap')

# %% [markdown]
# # Checking the type and length of the fetched data

# %%
print(type(df))
# Out:
# <class 'bs4.element.ResultSet'>

# %%
len(df)
# Out:
# 10

# %% [markdown]
# # Fetching needed data from the whole page

# %%
df_pdt1 = df[0]
df_pdt1
# Out:
# <div class="finder_snipet_wrap" data-row="1">
# <div class="filter filer_finder">
# <div class="filter-left filter_left">
# <span class="various_favorite fvrt_icon favorite_35593 gaclick" data-action="add" data-activityid="" data-category-id="553" data-href="" data-pro-name="Xiaomi Mi 10i 8GB RAM price in India" data-product-id="35593" data-type="favourite" rel="nofollow" title="Add to favourites"></span>
# <span class="finder-image-box target_link_new_tab" data-href-url="xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod" target="_blank">
# <img alt="Xiaomi Mi 10i 8GB RAM price in India" class="finder_pro_image fimage gaclick" data-type="image" src="//www.91-img.com/pictures/142055-v2-xiaomi-mi-10i-8gb-ram-mobile-phone-medium-1.jpg?tr=q-60" title="Xiaomi Mi 10i 8GB RAM"/>
# </span>
# <div class="compare1 padL10"><span cat="mobile" class="compare-button gaclick" data-comp-add-text="Compare" data-comp-added-text="Compare" data-image="//www.91-img.com/pictures/142055-v2-xiaomi-mi-10i-8gb-ram-mobile-phone-medium-1.jpg?tr=q-60" data-type="compare" pid="553_35593" value="553_35593">+ Compare</span>
# </div>
# </div>
# <div class="filter-grey-bar">
# <div class="filter-main">
# <div class="rank_rating margin_top">
# <div class="various3 fancybox.iframe pointer gaclick" data-type="Knofindewmore" href="/product_detail_spec_score.php?cid=553_35593&amp;score=84" title="91score: 84">
# <div class="rating_box_new_list"> 84%</div>
# </div>
# <span class="a2 star star_width">
# <h3><a class="hover_blue_link name gaclick" data-type="name" href="/xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod" target="_blank" title="Xiaomi Mi 10i 8GB RAM">Xiaomi Mi 10i 8GB RAM</a></h3>
# <div class="os_icon_cat">
# <span class="finder_icon icn_android"></span>
#                           Android v10 (Q)                        </div>
# </span>
# </div>
# </div>
# <div class="filter-right">
# <div align="right" class="filter-right2">
# <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>23,999</span>
# <p class="price_link">See more prices<span class="finder_icon icn_downarrow"></span></p>
# </div>
# </div>
# <div class="exp_comnt_pnl" style="white-space: unset;">
# <p id="descPart1_35593"><b>Expert comment:</b>
#                             Quite simply put, Xiaomi Mi 10i is one of the best phones, if not the best, in this price segment. The handset packs, an extremely capable chipset, a whopping 108MP primary camera, display with butter-smooth 120Hz refresh rate, and comes with support for 5G connectivity. If you're planning to buy a new phone around this price, Mi 10i is one of the best bets. Whether it is design or performance, this phone will likely impress you in most departments.
#                         </p>
# </div>
# <div class="filter-grey-bar filter_gray_bar_margin">
# <li class="left">Performance
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Performance_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Performance">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Performance_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="verygood" style="width:83%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="Octa core (2.2 GHz, Dual Core + 1.8 GHz, Hexa Core)">Octa core (2.2 GHz, Dual Core + 1.8 GHz, Hexa Core)</label><br/><label class="" title="Snapdragon 750G">Snapdragon 750G</label><br/><label class="" title="8 GB RAM">8 GB RAM</label><br/></div></li><li class="left">Display
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Display_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Display">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Display_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="good" style="width:64%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="6.67 inches (16.94 cm)">6.67 inches (16.94 cm)</label><br/><label class="" title="395 PPI, IPS LCD">395 PPI, IPS LCD</label><br/><label class="" title="120 Hz Refresh Rate">120 Hz Refresh Rate</label><br/></div></li><li class="left">Camera
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Camera_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Camera">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Camera_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="verygood" style="width:75%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="108 + 8 + 2 + 2 MP Quad Primary Cameras">108 + 8 + 2 + 2 MP Quad Primary Cameras</label><br/><label class="" title="Dual-color LED Flash">Dual-color LED Flash</label><br/><label class="" title="16 MP Front Camera">16 MP Front Camera</label><br/></div></li><li class="left">Battery
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Battery_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Battery">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Battery_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="excellent" style="width:88%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="4820 mAh">4820 mAh</label><br/><label class="" title="Fast Charging">Fast Charging</label><br/><label class="" title="USB Type-C Port">USB Type-C Port</label><br/></div></li> </div>
# <div class="clear"></div>
# <div class="filter-price-box">
# <div class="price-box">
# <div class="price-box-left">Prices</div>
# <div class="price-box-main"></div>
# <div class="price-box-right"></div>
# <div class="price-box-main2" data-prod-id="35593">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody>
# <tr class="target_link_external priceRow btm_line" data-href-url="/redir.php?origin=top10-mob&amp;mobileid=35593&amp;storename=amazon.in&amp;merid=100&amp;cc=">
# <td class="column" valign="bottom"><img class="lazyload_img" data-imgsrc="https://www.91-img.com/sourceimg/1505825980.png?tr=h-23,w-75,q-60,c-at_max" height="23"/></td>
# <td align="center" class="column text"><span class="WebRupee fprmrg">Rs.</span> 23,999                                                </td>
# <td class="buyNowPrice"><span class="column search_buttn buy_btn_finder" data-href-url="/redir.php?origin=top10-mob&amp;mobileid=35593&amp;storename=amazon.in&amp;merid=100&amp;cc=" rel="nofollow" target="_blank">BUY</span>
# </td>
# </tr>
# <tr>
# <td align="center" class="blue fppad" colspan="3"><span class="blue target_link_new_tab gaclick" data-href-url="xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod#store_prices" data-type="View all prices" target="_blank">View All Prices</span><span class="finder_icon icn_bluearrow stlink"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="filter filer_btm_margin">
# <div class="compare1"><span> </span></div>
# <div class="compare2" style="width:auto;margin-right:5px;">
# <div class="tooltip finder_icon icn_storage" data-title="128 GB + 512 GB Expandable"></div> <div class="finder_icon_storage_text">128 GB </div>
# <div class="tooltip finder_icon icn_dual_sim" data-title="Dual SIM: Nano + Nano (Hybrid)"></div> <div class="tooltip finder_icon icn_fiveg" data-title="Supported by device"></div> <div class="tooltip finder_icon icn_fourg" data-title="Supports Indian bands"></div> <div class="tooltip finder_icon icn_volte" data-title="VoLTE"></div> <div class="tooltip finder_icon icn_fingerprint" data-title="Fingerprint sensor"></div> <div class="tooltip finder_icon icn_gorilla_glass" data-title="Gorilla Glass 5"></div> </div>
# <div align="right" class="compare3"><span class="blue target_link_new_tab gaclick" data-href-url="xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod#specifications" data-type="See Full Specs">See Full Specifications
#               <span class="finder_icon icn_bluearrow"></span>
# </span>
# </div>
# <div class="compare4">
# <div class="featuretext">"The phone with the highest camera resolution"</div>
# </div>
# <div style="height: 0px;width: 100%;clear: both;"></div>
# </div>
# </div>

# %%
df_pdt1.div
# Out:
# <div class="filter filer_finder">
# <div class="filter-left filter_left">
# <span class="various_favorite fvrt_icon favorite_35593 gaclick" data-action="add" data-activityid="" data-category-id="553" data-href="" data-pro-name="Xiaomi Mi 10i 8GB RAM price in India" data-product-id="35593" data-type="favourite" rel="nofollow" title="Add to favourites"></span>
# <span class="finder-image-box target_link_new_tab" data-href-url="xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod" target="_blank">
# <img alt="Xiaomi Mi 10i 8GB RAM price in India" class="finder_pro_image fimage gaclick" data-type="image" src="//www.91-img.com/pictures/142055-v2-xiaomi-mi-10i-8gb-ram-mobile-phone-medium-1.jpg?tr=q-60" title="Xiaomi Mi 10i 8GB RAM"/>
# </span>
# <div class="compare1 padL10"><span cat="mobile" class="compare-button gaclick" data-comp-add-text="Compare" data-comp-added-text="Compare" data-image="//www.91-img.com/pictures/142055-v2-xiaomi-mi-10i-8gb-ram-mobile-phone-medium-1.jpg?tr=q-60" data-type="compare" pid="553_35593" value="553_35593">+ Compare</span>
# </div>
# </div>
# <div class="filter-grey-bar">
# <div class="filter-main">
# <div class="rank_rating margin_top">
# <div class="various3 fancybox.iframe pointer gaclick" data-type="Knofindewmore" href="/product_detail_spec_score.php?cid=553_35593&amp;score=84" title="91score: 84">
# <div class="rating_box_new_list"> 84%</div>
# </div>
# <span class="a2 star star_width">
# <h3><a class="hover_blue_link name gaclick" data-type="name" href="/xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod" target="_blank" title="Xiaomi Mi 10i 8GB RAM">Xiaomi Mi 10i 8GB RAM</a></h3>
# <div class="os_icon_cat">
# <span class="finder_icon icn_android"></span>
#                           Android v10 (Q)                        </div>
# </span>
# </div>
# </div>
# <div class="filter-right">
# <div align="right" class="filter-right2">
# <span class="price price_padding"><span class="WebRupee web_rupee_padding">Rs.</span>23,999</span>
# <p class="price_link">See more prices<span class="finder_icon icn_downarrow"></span></p>
# </div>
# </div>
# <div class="exp_comnt_pnl" style="white-space: unset;">
# <p id="descPart1_35593"><b>Expert comment:</b>
#                             Quite simply put, Xiaomi Mi 10i is one of the best phones, if not the best, in this price segment. The handset packs, an extremely capable chipset, a whopping 108MP primary camera, display with butter-smooth 120Hz refresh rate, and comes with support for 5G connectivity. If you're planning to buy a new phone around this price, Mi 10i is one of the best bets. Whether it is design or performance, this phone will likely impress you in most departments.
#                         </p>
# </div>
# <div class="filter-grey-bar filter_gray_bar_margin">
# <li class="left">Performance
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Performance_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Performance">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Performance_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="verygood" style="width:83%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="Octa core (2.2 GHz, Dual Core + 1.8 GHz, Hexa Core)">Octa core (2.2 GHz, Dual Core + 1.8 GHz, Hexa Core)</label><br/><label class="" title="Snapdragon 750G">Snapdragon 750G</label><br/><label class="" title="8 GB RAM">8 GB RAM</label><br/></div></li><li class="left">Display
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Display_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Display">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Display_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="good" style="width:64%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="6.67 inches (16.94 cm)">6.67 inches (16.94 cm)</label><br/><label class="" title="395 PPI, IPS LCD">395 PPI, IPS LCD</label><br/><label class="" title="120 Hz Refresh Rate">120 Hz Refresh Rate</label><br/></div></li><li class="left">Camera
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Camera_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Camera">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Camera_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="verygood" style="width:75%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="108 + 8 + 2 + 2 MP Quad Primary Cameras">108 + 8 + 2 + 2 MP Quad Primary Cameras</label><br/><label class="" title="Dual-color LED Flash">Dual-color LED Flash</label><br/><label class="" title="16 MP Front Camera">16 MP Front Camera</label><br/></div></li><li class="left">Battery
#                   <div class="key_features_popup">
# <span class="downarrow expand" ga_segment_name="Best Mobile Phones Under 25000" href="javascript:void(0);" post_segment_id="" product_id="35593" product_url="xiaomi-mi-10i-8gb-ram-price-in-india" response_div="res_Battery_35593" segment_ga_pro_name="Xiaomi Mi 10i 8GB RAM::35593::553" segment_mob_price="23069" segment_name="Battery">
# <span class="arrow_bottom"></span>
# <div class="btm_div btm btn_width">
# <div class="btm_child" id="res_Battery_35593"></div>
# </div>
# </span>
# </div><p><div class="mtr_bar_div">
# <div class="excellent" style="width:88%;">
# <span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span><span class="mtr_bar"></span>
# </div>
# </div></p><div class="a filter-list-text"><label class="" title="4820 mAh">4820 mAh</label><br/><label class="" title="Fast Charging">Fast Charging</label><br/><label class="" title="USB Type-C Port">USB Type-C Port</label><br/></div></li> </div>
# <div class="clear"></div>
# <div class="filter-price-box">
# <div class="price-box">
# <div class="price-box-left">Prices</div>
# <div class="price-box-main"></div>
# <div class="price-box-right"></div>
# <div class="price-box-main2" data-prod-id="35593">
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody>
# <tr class="target_link_external priceRow btm_line" data-href-url="/redir.php?origin=top10-mob&amp;mobileid=35593&amp;storename=amazon.in&amp;merid=100&amp;cc=">
# <td class="column" valign="bottom"><img class="lazyload_img" data-imgsrc="https://www.91-img.com/sourceimg/1505825980.png?tr=h-23,w-75,q-60,c-at_max" height="23"/></td>
# <td align="center" class="column text"><span class="WebRupee fprmrg">Rs.</span> 23,999                                                </td>
# <td class="buyNowPrice"><span class="column search_buttn buy_btn_finder" data-href-url="/redir.php?origin=top10-mob&amp;mobileid=35593&amp;storename=amazon.in&amp;merid=100&amp;cc=" rel="nofollow" target="_blank">BUY</span>
# </td>
# </tr>
# <tr>
# <td align="center" class="blue fppad" colspan="3"><span class="blue target_link_new_tab gaclick" data-href-url="xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod#store_prices" data-type="View all prices" target="_blank">View All Prices</span><span class="finder_icon icn_bluearrow stlink"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
df_pdt1.a
# Out:
# <a class="hover_blue_link name gaclick" data-type="name" href="/xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod" target="_blank" title="Xiaomi Mi 10i 8GB RAM">Xiaomi Mi 10i 8GB RAM</a>

# %%
df_pdt1.h3
# Out:
# <h3><a class="hover_blue_link name gaclick" data-type="name" href="/xiaomi-mi-10i-8gb-ram-price-in-india?utm_source=91m&amp;utm_medium=top10&amp;utm_campaign=midprod" target="_blank" title="Xiaomi Mi 10i 8GB RAM">Xiaomi Mi 10i 8GB RAM</a></h3>

# %% [markdown]
# # Name of product

# %%
df_pdt1 = df_pdt1.h3.a.text
df_pdt1
# Out:
# 'Xiaomi Mi 10i 8GB RAM'

# %% [markdown]
# # Percentage rating of product

# %%
df_rating = soup.find('div',class_='rating_box_new_list')
df_rating.get_text().strip()
# Out:
# '84%'

# %% [markdown]
# # Ram of Product

# %%
df_ram = soup.find('div',class_='a filter-list-text').contents[4]
df_ram.text
# Out:
# '8 GB RAM'

# %% [markdown]
# # Version of product

# %%
df_vers1 = soup.find('div', class_='os_icon_cat')
df_vers1.get_text().strip()
# Out:
# 'Android v10 (Q)'

# %% [markdown]
# # Price of product

# %%
df_pric1 = soup.find('span',class_='price price_padding').contents[1]
df_pric1
# Out:
# '23,999'

# %% [markdown]
# # Fetching data of whole products

# %%
names = []
android_version = []
price = []
ram_memory = []
rating = []
for details in df:
    ###if details.find()
    name = details.h3.a.text
    names.append(name)
    
    version = details.find('div', class_='os_icon_cat').get_text().strip()
    android_version.append(version)
    
    ram = details.find('div',class_='a filter-list-text').contents[4].get_text().strip()
    ram_memory.append(ram)
    
    rate = details.find('div',class_='rating_box_new_list').get_text().strip()
    rating.append(rate)
    
    prices = details.find('span',class_='price price_padding').contents[1]
    price.append(prices)

# %% [markdown]
# # Making dataframe with the fetched data

# %%
test_df = pd.DataFrame({
    'Mobile_name' :names,
    'Version' :android_version,
    'RAM':ram_memory,
    'Rating':rating,
    'Price(Rs)':price
})
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Mobile_name  10 non-null     object
#  1   Version      10 non-null     object
#  2   RAM          10 non-null     object
#  3   Rating       10 non-null     object
#  4   Price(Rs)    10 non-null     object
# dtypes: object(5)
# memory usage: 528.0+ bytes
# None
#               Mobile_name          Version       RAM Rating Price(Rs)
# 0   Xiaomi Mi 10i 8GB RAM  Android v10 (Q)  8 GB RAM    84%    23,999
# 1      Samsung Galaxy M51  Android v10 (Q)  6 GB RAM    87%    22,999
# 2     Realme Narzo 30 Pro  Android v10 (Q)  6 GB RAM    85%    17,621
# 3               Moto G 5G  Android v10 (Q)  6 GB RAM    85%    21,899
# 4    Realme 8 Pro 8GB RAM      Android v11  8 GB RAM    86%    20,500
# 5                Vivo V20      Android v11  8 GB RAM    86%    21,414
# 6  Xiaomi Poco X3 8GB RAM  Android v10 (Q)  8 GB RAM    84%    20,999
# 7    Xiaomi Poco X2 128GB  Android v10 (Q)  6 GB RAM    84%    17,990
# 8      Realme 6 Pro 128GB  Android v10 (Q)  6 GB RAM    84%    18,650
# 9            OPPO F17 Pro  Android v10 (Q)  8 GB RAM    85%    21,490

# %% [markdown]
# # Basic EDA

# %%
test_df.describe()
# Out:
#        Mobile_name          Version       RAM Rating Price(Rs)
# count           10               10        10     10        10
# unique          10                2         2      4        10
# top       Vivo V20  Android v10 (Q)  6 GB RAM    84%    21,414
# freq             1                8         5      4         1

# %%
test_df.isnull().sum()
# Out:
# Mobile_name    0
# Version        0
# RAM            0
# Rating         0
# Price(Rs)      0
# dtype: int64

# %%
test_df.shape
# Out:
# (10, 5)

# %%
test_df.columns
# Out:
# Index(['Mobile_name', 'Version', 'RAM', 'Rating', 'Price(Rs)'], dtype='object')

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(test_df['Rating'],test_df['Price(Rs)'])

# %% [markdown]
# From the Scatter plot we can say that price of the product and its percentage ratings.There are 4 prodcuts in 84% rating which is the most one.The mobile with maximum price has percentage rating of 84%.In the same way the mobile with lower price has 85% rating.

# %% [markdown]
# # Histogram representation

# %%
colors = ['yellow']
labels = ['% rating']
plt.style.use('ggplot')
plt.hist(test_df['Rating'],density = True ,color = colors,label= labels,bins= 15)
plt.title('% Rating of 10 mobile phones under 25000 ')
# Out:
# Text(0.5, 1.0, '% Rating of 10 mobile phones under 25000 ')

# %%
plt.hist(test_df['RAM'],bins=15,color = 'green')
plt.title('RAM spec for top mobiles under 25000')
# Out:
# Text(0.5, 1.0, 'RAM spec for top mobiles under 25000')

# %% [markdown]
# From the histogram for the RAM we can say that 4 phones in the list are having 8GB RAM and remaing 6 phones ar having 6GB RAM
